# %%
import numpy as np
import pandas as pd
import os
import decimal
from math import *
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#Import
cwd = os.getcwd()
path = cwd.replace('FinalProject/preprocessing/exploration','FinalProject/preprocessing/cleaning/cleaned')
df = pd.read_csv(path)
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0       Female     Loyal Customer   52  Business travel       Eco
# 1       Female     Loyal Customer   36  Business travel  Business
# 2         Male  disloyal Customer   20  Business travel       Eco
# 3         Male     Loyal Customer   44  Business travel  Business
# 4       Female     Loyal Customer   49  Business travel       Eco
# ...        ...                ...  ...              ...       ...
# 129482  Female  disloyal Customer   23  Business travel       Eco
# 129483    Male     Loyal Customer   49  Business travel  Business
# 129484    Male  disloyal Customer   30  Business travel  Business
# 129485  Female  disloyal Customer   22  Business travel       Eco
# 129486    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   160                      5
# 1                  2863                      1
# 2                   192                      2
# 3                  3377                      0
# 4                  1182                      2
# ...                 ...                    ...
# 129482              192                      2
# 129483             2347                      4
# 129484             1995                      1
# 129485             1000                      1
# 129486             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       1                       3
# 2                                       0                       2
# 3                                       0                       0
# 4                                       3                       4
# ...                                   ...                     ...
# 129482                                  1                       2
# 129483                                  4                       4
# 129484                                  1                       1
# 129485                                  1                       1
# 129486                                  3                       3
#
#         Gate location  ...  On-board service  Leg room service  \
# 0                   4  ...                 5                 5
# 1                   1  ...                 4                 4
# 2                   4  ...                 4                 1
# 3                   2  ...                 1                 1
# 4                   3  ...                 2                 2
# ...               ...  ...               ...               ...
# 129482              3  ...                 3                 1
# 129483              4  ...                 5                 5
# 129484              3  ...                 3                 2
# 129485              5  ...                 4                 5
# 129486              3  ...                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      5                2                 5            5
# 1                      4                3                 4            5
# 2                      3                2                 2            2
# 3                      1                3                 1            4
# 4                      2                4                 2            4
# ...                  ...              ...               ...          ...
# 129482                 4                2                 3            2
# 129483                 5                5                 5            4
# 129484                 4                5                 5            4
# 129485                 1                5                 4            1
# 129486                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction  \
# 0                               50                      44.0             1
# 1                                0                       0.0             1
# 2                                0                       0.0             0
# 3                                0                       6.0             1
# 4                                0                      20.0             1
# ...                            ...                       ...           ...
# 129482                           3                       0.0             0
# 129483                           0                       0.0             1
# 129484                           7                      14.0             0
# 129485                           0                       0.0             0
# 129486                           0                       0.0             0
#
#            id
# 0       19556
# 1       90035
# 2       12360
# 3       77959
# 4       36875
# ...       ...
# 129482  94171
# 129483  73097
# 129484  68825
# 129485  54173
# 129486  62567
#
# [129487 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction', 'id'],
#       dtype='object')

# %%
#Prediction column
df['satisfaction'].unique()
# Out:
# array(['satisfied', 'neutral or dissatisfied'], dtype=object)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Univariate Analysis
# For continuous variables (all of the variables excluding “Age”), develop boxplots and/or histograms independently
# For the “Age” variable, develop bar charts to identify frequencies

# %% [markdown]
# ## Bivariate Analysis
# For continuous variables (all of the variables excluding “Age”), develop scatterplots and lineplots between the continuous variable in relation to the “satisfaction” variable.
# Develop a column chart between the “age” variable and the “satisfaction” variable
